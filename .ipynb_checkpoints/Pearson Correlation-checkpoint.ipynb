# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('CBC Report.csv')
df.head()
# Out:
#         Serial      Date  Gender   Age  Haemoglobin   ESR    WBC  Neutrophil  \
# 0  A2308164543  2/8/2023  Female  40.0         11.2  32.0  11.30          65
# 1  A2308164502  2/8/2023    Male  13.0         11.6  59.0   7.80          49
# 2  A2308164673  3/8/2023    Male  23.0         15.1   NaN   3.85          65
# 3  A2308164685  3/8/2023    Male  58.0          8.5   NaN  10.30          85
# 4  A2308164626  2/8/2023  Female  35.0         12.0  28.0   6.70          54
#
#    Lymphocyte  Monocyte  Eosinophil  Basophil   RBC  Platelets    Result
# 0        23.0      10.0         2.0       0.0  4.04         30  Positive
# 1        42.0       9.0         0.0       0.0  4.34         40  Positive
# 2        25.0       9.0         1.0       0.0  5.43         30  Positive
# 3         6.0       6.0         3.0       0.0  3.00         30  Positive
# 4        20.0       4.0         1.0       0.0  4.30         40  Positive

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 255 entries, 0 to 300
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Serial       255 non-null    object
#  1   Date         255 non-null    object
#  2   Gender       255 non-null    object
#  3   Age          255 non-null    float64
#  4   Haemoglobin  255 non-null    float64
#  5   ESR          255 non-null    float64
#  6   WBC          255 non-null    float64
#  7   Neutrophil   255 non-null    int64
#  8   Lymphocyte   255 non-null    float64
#  9   Monocyte     255 non-null    float64
#  10  Eosinophil   255 non-null    float64
#  11  Basophil     255 non-null    float64
#  12  RBC          255 non-null    float64
#  13  Platelets    255 non-null    int64
#  14  Result       255 non-null    object
# dtypes: float64(9), int64(2), object(4)
# memory usage: 31.9+ KB

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Serial         0
# Date           0
# Gender         0
# Age            0
# Haemoglobin    0
# ESR            0
# WBC            0
# Neutrophil     0
# Lymphocyte     0
# Monocyte       0
# Eosinophil     0
# Basophil       0
# RBC            0
# Platelets      0
# Result         0
# dtype: int64

# %%
del df['Serial']
del df['Date']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 255 entries, 0 to 300
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gender       255 non-null    object
#  1   Age          255 non-null    float64
#  2   Haemoglobin  255 non-null    float64
#  3   ESR          255 non-null    float64
#  4   WBC          255 non-null    float64
#  5   Neutrophil   255 non-null    int64
#  6   Lymphocyte   255 non-null    float64
#  7   Monocyte     255 non-null    float64
#  8   Eosinophil   255 non-null    float64
#  9   Basophil     255 non-null    float64
#  10  RBC          255 non-null    float64
#  11  Platelets    255 non-null    int64
#  12  Result       255 non-null    object
# dtypes: float64(9), int64(2), object(2)
# memory usage: 27.9+ KB

# %%
sns.countplot(x='Result',data=df, palette='hls')
plt.show()
#plt.savefig('count_plot') mal: the nodule malignancy, 0: benign, 1: malignant

# %%
sns.countplot(x='Gender',data=df, palette='hls')
plt.show()
#plt.savefig('count_plot') mal: the nodule malignancy, 0: benign, 1: malignant

# %%
plt.figure(figsize = (10,5))
sns.heatmap(df.corr(), annot = True, cmap="rainbow")
plt.show()

# %%
# Import label encoder 
from sklearn import preprocessing 

# label_encoder object knows 
# how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 

# Encode labels in column 'species'. 
df['Gender']= label_encoder.fit_transform(df['Gender'])
df['Result']= label_encoder.fit_transform(df['Result'])

# %%
X = df.drop(["Result"],axis =1)
y = df["Result"]

# %% [markdown]
# # FS

# %%
#Using Correlation
plt.figure(figsize=(12,10))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
#Correlation with output variable
cor_target = abs(cor["Result"])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.1]
relevant_features
# Out:
# Gender         0.177062
# Haemoglobin    0.197176
# ESR            0.237171
# WBC            0.190751
# Neutrophil     0.321915
# Lymphocyte     0.257766
# Monocyte       0.283395
# RBC            0.197834
# Platelets      0.746133
# Result         1.000000
# Name: Result, dtype: float64

# %%
X_fea = df[['Gender','Haemoglobin','ESR','WBC','Neutrophil','Lymphocyte','Monocyte','RBC','Platelets']]
y_fea = df['Result']

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2)
X_res, y_res = sm.fit_resample(X_fea,y_fea)

# %%
ML_Model = []
accuracy = []
precision = []
f1score = []
recall = []
auc = []

#function to call for storing the results
def storeResults(model, a,b,c,d,e):
    ML_Model.append(model)
    accuracy.append(round(a, 3))
    precision.append(round(b, 3))
    recall.append(round(c, 3))
    f1score.append(round(d, 3))
    auc.append(round(e,3))

# %%
from sklearn.metrics import accuracy_score # for calculating accuracy of model
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score,roc_auc_score

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(X_res, y_res, test_size=0.20, random_state=42)
X_train.shape, y_train.shape, X_valid.shape, y_valid.shape
# Out:
# ((270, 9), (270,), (68, 9), (68,))

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(multi_class='ovr', solver='liblinear', C=1.0)
lr.fit(X_train, y_train)

y_pred    = lr.predict(X_valid)

lr_acc = accuracy_score(y_pred, y_valid)
lr_prec = precision_score(y_pred, y_valid,average='weighted')
lr_rec = recall_score(y_pred, y_valid,average='weighted')
lr_f1 = f1_score(y_pred, y_valid,average='weighted')
lr_auroc = roc_auc_score(y_train, lr.predict_proba(X_train)[:, 1])

# %%
storeResults('Logistic Regression',lr_acc,lr_prec,lr_rec,lr_f1,lr_auroc)

# %% [markdown]
# # SVM

# %%
from sklearn import svm
svc = svm.SVC(decision_function_shape='ovo',probability=True)
svc.fit(X_train, y_train)

y_pred    = svc.predict(X_valid)

svc_acc = accuracy_score(y_pred, y_valid)
svc_prec = precision_score(y_pred, y_valid,average='weighted')
svc_rec = recall_score(y_pred, y_valid,average='weighted')
svc_f1 = f1_score(y_pred, y_valid,average='weighted')
svc_auroc = roc_auc_score(y_train, svc.predict_proba(X_train)[:, 1])

# %%
storeResults('SVM',svc_acc,svc_prec,svc_rec,svc_f1,svc_auroc)

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train, y_train)

y_pred    = nb.predict(X_valid)

nb_acc = accuracy_score(y_pred, y_valid)
nb_prec = precision_score(y_pred, y_valid,average='weighted')
nb_rec = recall_score(y_pred, y_valid,average='weighted')
nb_f1 = f1_score(y_pred, y_valid,average='weighted')
nb_auroc = roc_auc_score(y_train, nb.predict_proba(X_train)[:, 1])

# %%
storeResults('NaiveBayes',nb_acc,nb_prec,nb_rec,nb_f1,nb_auroc)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()

rf.fit(X_train, y_train)

y_pred    = rf.predict(X_valid)

rf_acc = accuracy_score(y_pred, y_valid)
rf_prec = precision_score(y_pred, y_valid,average='weighted')
rf_rec = recall_score(y_pred, y_valid,average='weighted')
rf_f1 = f1_score(y_pred, y_valid,average='weighted')
rf_auroc = roc_auc_score(y_train, rf.predict_proba(X_train)[:, 1])

# %%
storeResults('RandomForest',rf_acc,rf_prec,rf_rec,rf_f1,rf_auroc)

# %% [markdown]
# # AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier(n_estimators=100, algorithm="SAMME", random_state=0)

ada.fit(X_train, y_train)

y_pred    = ada.predict(X_valid)

ada_acc = accuracy_score(y_pred, y_valid)
ada_prec = precision_score(y_pred, y_valid,average='weighted')
ada_rec = recall_score(y_pred, y_valid,average='weighted')
ada_f1 = f1_score(y_pred, y_valid,average='weighted')
ada_auroc = roc_auc_score(y_train, ada.predict_proba(X_train)[:, 1])

# %%
storeResults('AdaBoost',ada_acc,ada_prec,ada_rec,ada_f1,ada_auroc)

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(X_train, y_train)

y_pred    = xgb.predict(X_valid)

xgb_acc = accuracy_score(y_pred, y_valid)
xgb_prec = precision_score(y_pred, y_valid,average='weighted')
xgb_rec = recall_score(y_pred, y_valid,average='weighted')
xgb_f1 = f1_score(y_pred, y_valid,average='weighted')
xgb_auroc = roc_auc_score(y_train, xgb.predict_proba(X_train)[:, 1])

# %%
storeResults('XGBoost',xgb_acc,xgb_prec,xgb_rec,xgb_f1,xgb_auroc)

# %% [markdown]
# # MLP

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(random_state=1, max_iter=300)

mlp.fit(X_train, y_train)

y_pred    = mlp.predict(X_valid)

mlp_acc = accuracy_score(y_pred, y_valid)
mlp_prec = precision_score(y_pred, y_valid,average='weighted')
mlp_rec = recall_score(y_pred, y_valid,average='weighted')
mlp_f1 = f1_score(y_pred, y_valid,average='weighted')
mlp_auroc = roc_auc_score(y_train, mlp.predict_proba(X_train)[:, 1])

# %%
storeResults('MLP',mlp_acc,mlp_prec,mlp_rec,mlp_f1,mlp_auroc)

# %% [markdown]
# # LightGBM

# %%
from lightgbm import LGBMClassifier

lgbm = LGBMClassifier(n_estimators=10)
lgbm.fit(X_train, y_train)

y_pred    = lgbm.predict(X_valid)

lgbm_acc = accuracy_score(y_pred, y_valid)
lgbm_prec = precision_score(y_pred, y_valid,average='weighted')
lgbm_rec = recall_score(y_pred, y_valid,average='weighted')
lgbm_f1 = f1_score(y_pred, y_valid,average='weighted')
lgbm_auroc = roc_auc_score(y_train, lgbm.predict_proba(X_train)[:, 1])
# Out:
# [LightGBM] [Info] Number of positive: 126, number of negative: 144
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000140 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 483
# [LightGBM] [Info] Number of data points in the train set: 270, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.466667 -> initscore=-0.133531
# [LightGBM] [Info] Start training from score -0.133531
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
storeResults('LightGBM',lgbm_acc,lgbm_prec,lgbm_rec,lgbm_f1,lgbm_auroc)

# %% [markdown]
# # Stacking Classifier

# %%
from sklearn.ensemble import StackingClassifier, ExtraTreesClassifier
from lightgbm import LGBMClassifier

estimators = [('XGB', xgb),('LR', lr),('MLP', mlp)]

stac = StackingClassifier(estimators=estimators, final_estimator=LGBMClassifier(n_estimators=10))

# %%
stac.fit(X_train, y_train)

y_pred    = stac.predict(X_valid)

stac_acc = accuracy_score(y_pred, y_valid)
stac_prec = precision_score(y_pred, y_valid,average='weighted')
stac_rec = recall_score(y_pred, y_valid,average='weighted')
stac_f1 = f1_score(y_pred, y_valid,average='weighted')
stac_auroc = roc_auc_score(y_train, stac.predict_proba(X_train)[:, 1])
# Out:
# [LightGBM] [Info] Number of positive: 126, number of negative: 144
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000057 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 273
# [LightGBM] [Info] Number of data points in the train set: 270, number of used features: 3
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.466667 -> initscore=-0.133531
# [LightGBM] [Info] Start training from score -0.133531
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
storeResults('Proposed',stac_acc,stac_prec,stac_rec,stac_f1,stac_auroc)

# %% [markdown]
# # Extension

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.tree import DecisionTreeClassifier

bdt = AdaBoostClassifier(
    DecisionTreeClassifier(max_depth=1), algorithm="SAMME", n_estimators=200
)
tree = ExtraTreesClassifier()

clf = VotingClassifier(estimators= [('BoostedDT', bdt),('ET', tree)], voting='soft')

clf.fit(X_train, y_train)

y_pred    = clf.predict(X_valid)

vot_acc = accuracy_score(y_pred, y_valid)
vot_prec = precision_score(y_pred, y_valid,average='weighted')
vot_rec = recall_score(y_pred, y_valid,average='weighted')
vot_f1 = f1_score(y_pred, y_valid,average='weighted')
vot_auroc = roc_auc_score(y_train, clf.predict_proba(X_train)[:, 1])

# %%
storeResults('Extension',vot_acc,vot_prec,vot_rec,vot_f1,vot_auroc)

# %% [markdown]
# # FNN

# %%
import tensorflow as tf
#import tensorflow_hub as hub

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
        
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train, batch_size=2, epochs=20, 
         validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 135/135 [==============================] - 1s 4ms/step - loss: 4.9336 - accuracy: 0.6444 - val_loss: 0.6399 - val_accuracy: 0.8235
# Epoch 2/20
# 135/135 [==============================] - 0s 4ms/step - loss: 0.3237 - accuracy: 0.8704 - val_loss: 0.6031 - val_accuracy: 0.8382
# Epoch 3/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2985 - accuracy: 0.8778 - val_loss: 0.5124 - val_accuracy: 0.8676
# Epoch 4/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2821 - accuracy: 0.8852 - val_loss: 0.5293 - val_accuracy: 0.8529
# Epoch 5/20
# 135/135 [==============================] - 1s 4ms/step - loss: 0.2603 - accuracy: 0.8963 - val_loss: 0.3725 - val_accuracy: 0.8382
# Epoch 6/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2575 - accuracy: 0.8778 - val_loss: 0.6562 - val_accuracy: 0.8088
# Epoch 7/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2486 - accuracy: 0.8926 - val_loss: 0.4191 - val_accuracy: 0.8529
# Epoch 8/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2566 - accuracy: 0.8741 - val_loss: 0.3168 - val_accuracy: 0.8676
# Epoch 9/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2615 - accuracy: 0.8852 - val_loss: 0.3722 - val_accuracy: 0.8529
# Epoch 10/20
# 135/135 [==============================] - 0s 4ms/step - loss: 0.2474 - accuracy: 0.9000 - val_loss: 0.3239 - val_accuracy: 0.8235
# Epoch 11/20
# 135/135 [==============================] - 0s 4ms/step - loss: 0.2402 - accuracy: 0.8704 - val_loss: 0.2989 - val_accuracy: 0.8824
# Epoch 12/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2435 - accuracy: 0.8741 - val_loss: 0.5411 - val_accuracy: 0.8382
# Epoch 13/20
# 135/135 [==============================] - 0s 4ms/step - loss: 0.2443 - accuracy: 0.9000 - val_loss: 0.3252 - val_accuracy: 0.8529
# Epoch 14/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2371 - accuracy: 0.9037 - val_loss: 0.3161 - val_accuracy: 0.8676
# Epoch 15/20
# 135/135 [==============================] - 0s 4ms/step - loss: 0.2362 - accuracy: 0.8704 - val_loss: 0.5564 - val_accuracy: 0.8382
# Epoch 16/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2256 - accuracy: 0.9000 - val_loss: 0.2783 - val_accuracy: 0.8971
# Epoch 17/20
# 135/135 [==============================] - 0s 4ms/step - loss: 0.2167 - accuracy: 0.8963 - val_loss: 0.4755 - val_accuracy: 0.8529
# Epoch 18/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2166 - accuracy: 0.9074 - val_loss: 0.5335 - val_accuracy: 0.8382
# Epoch 19/20
# 135/135 [==============================] - 0s 4ms/step - loss: 0.2139 - accuracy: 0.9037 - val_loss: 0.3510 - val_accuracy: 0.8824
# Epoch 20/20
# 135/135 [==============================] - 0s 4ms/step - loss: 0.2047 - accuracy: 0.9037 - val_loss: 0.2907 - val_accuracy: 0.8676

# %%
y_pred = model.predict(X_valid)
# Out:
# 3/3 [==============================] - 0s 1000us/step

# %%
y_pred = (y_pred > 0.5)

nn_acc = accuracy_score(y_pred, y_valid)
nn_prec = precision_score(y_pred, y_valid,average='weighted')
nn_f1 = f1_score(y_pred, y_valid,average='weighted')
nn_auroc = roc_auc_score(y_train, clf.predict_proba(X_train)[:, 1])
nn_rec = recall_score(y_pred, y_valid,average='weighted')

# %%
storeResults('FNN',nn_acc,nn_prec,nn_rec,nn_f1,nn_auroc)

# %% [markdown]
# # ANN

# %%
from tensorflow.keras import models, layers, optimizers, regularizers
import numpy as np
import random
from sklearn import model_selection, preprocessing
import tensorflow as tf
from tqdm import tqdm

# %%
# splitting the dataset 80% for training and 20% testing
X_train, X_test, y_train, y_test = train_test_split(X_res,y_res, test_size=0.20, random_state=42)

# %%
x_train = preprocessing.normalize(X_train)
x_test = preprocessing.normalize(X_test)

# %%
hidden_units = 10     # how many neurons in the hidden layer
activation = 'relu'   # activation function for hidden layer
l2 = 0.01             # regularization - how much we penalize large parameter values
learning_rate = 0.01  # how big our steps are in gradient descent
epochs = 5            # how many epochs to train for
batch_size = 2       # how many samples to use for each gradient descent update

# %%
# create a sequential model
model2 = models.Sequential()

# add the hidden layer
model2.add(layers.Dense(input_dim=9,
                       units=hidden_units, 
                       activation=activation))

# add the output layer
model2.add(layers.Dense(input_dim=hidden_units,
                       units=1,
                       activation='sigmoid'))

# define our loss function and optimizer
model2.compile(loss='binary_crossentropy',
              # Adam is a kind of gradient descent
              optimizer=optimizers.Adam(lr=learning_rate),
              metrics=['accuracy'])

# %%
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 10)                100
#
#  dense_6 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 111
# Trainable params: 111
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model2.fit(x_train, y_train, epochs=20, batch_size=batch_size)
# Out:
# Epoch 1/20
# 135/135 [==============================] - 1s 3ms/step - loss: 0.5696 - accuracy: 0.7148
# Epoch 2/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.3260 - accuracy: 0.8704
# Epoch 3/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2720 - accuracy: 0.8889
# Epoch 4/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2679 - accuracy: 0.8778
# Epoch 5/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2638 - accuracy: 0.8889
# Epoch 6/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2600 - accuracy: 0.8926
# Epoch 7/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2549 - accuracy: 0.9000
# Epoch 8/20
# 135/135 [==============================] - 0s 2ms/step - loss: 0.2563 - accuracy: 0.8963
# Epoch 9/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2652 - accuracy: 0.8889
# Epoch 10/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2669 - accuracy: 0.8889
# Epoch 11/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2539 - accuracy: 0.9000
# Epoch 12/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2542 - accuracy: 0.8889
# Epoch 13/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2501 - accuracy: 0.9000
# Epoch 14/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2605 - accuracy: 0.8963
# Epoch 15/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2497 - accuracy: 0.9000
# Epoch 16/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2555 - accuracy: 0.8926
# Epoch 17/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2497 - accuracy: 0.9037
# Epoch 18/20
# 135/135 [==============================] - 0s 3ms/step - loss: 0.2606 - accuracy: 0.8963
# Epoch 19/20
# 135/135 [==============================] - 0s 2ms/step - loss: 0.2654 - accuracy: 0.8963
# Epoch 20/20
# 135/135 [==============================] - 0s 2ms/step - loss: 0.2508 - accuracy: 0.9074

# %%
# Plot of accuracy vs epoch for train and test dataset
plt.plot(history.history['accuracy'])
#plt.plot(history.history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# Plot of loss vs epoch for train and test dataset
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
y_pred = model2.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dnn_acc = accuracy_score(y_pred, y_test)
dnn_prec = precision_score(y_pred, y_test,average='weighted')
dnn_rec = recall_score(y_pred, y_test,average='weighted')
dnn_f1 = f1_score(y_pred, y_test,average='weighted')
dnn_auroc = roc_auc_score(y_train, clf.predict_proba(X_train)[:, 1])
# Out:
# 3/3 [==============================] - 0s 2ms/step

# %%
storeResults('ANN',dnn_acc,dnn_prec,dnn_rec,dnn_f1,dnn_auroc)

# %% [markdown]
# # CNN

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D
from keras.layers import Dense, Conv1D, MaxPool1D, Flatten, Dropout # importing dense layer
from keras.models import Sequential #importing Sequential layer
from keras.layers import Input
from keras.models import Model

# %%
# splitting the dataset 80% for training and 20% testing
X_train, X_test, y_train, y_test = train_test_split(X_res,y_res, test_size=0.20, random_state=42)

# %%
X_train=X_train.values
X_test=X_test.values

X_train = X_train.reshape(-1, X_train.shape[1],1)
X_test = X_test.reshape(-1, X_test.shape[1],1)

Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)

# %%
verbose, epoch, batch_size = 1, 100, 2
activationFunction='relu'

def CNN():
    
    cnnmodel = Sequential()
    cnnmodel.add(Conv1D(filters=128, kernel_size=2, activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
    cnnmodel.add(MaxPooling1D(pool_size=2))
    cnnmodel.add(Dropout(rate=0.2))
    cnnmodel.add(Flatten())
    cnnmodel.add(Dense(2, activation='softmax'))
    cnnmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    cnnmodel.summary()
    return cnnmodel

cnnmodel = CNN()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 8, 128)            384
#
#  max_pooling1d_1 (MaxPooling  (None, 4, 128)           0
#  1D)
#
#  dropout_1 (Dropout)         (None, 4, 128)            0
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_8 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 1,410
# Trainable params: 1,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelhistory = cnnmodel.fit(X_train, Y_train, epochs=20, verbose=verbose, validation_split=0.2, batch_size = batch_size)
# Out:
# Epoch 1/20
# 108/108 [==============================] - 4s 4ms/step - loss: 1.2685 - accuracy: 0.7176 - val_loss: 1.2976 - val_accuracy: 0.8148
# Epoch 2/20
# 108/108 [==============================] - 0s 3ms/step - loss: 0.7742 - accuracy: 0.8519 - val_loss: 1.2318 - val_accuracy: 0.8333
# Epoch 3/20
# 108/108 [==============================] - 0s 3ms/step - loss: 0.8230 - accuracy: 0.8519 - val_loss: 1.3562 - val_accuracy: 0.8148
# Epoch 4/20
# 108/108 [==============================] - 0s 3ms/step - loss: 0.7484 - accuracy: 0.8611 - val_loss: 0.6091 - val_accuracy: 0.8519
# Epoch 5/20
# 108/108 [==============================] - 0s 3ms/step - loss: 0.7736 - accuracy: 0.8472 - val_loss: 0.5600 - val_accuracy: 0.8333
# Epoch 6/20
# 108/108 [==============================] - 0s 3ms/step - loss: 0.9337 - accuracy: 0.8472 - val_loss: 0.9428 - val_accuracy: 0.8333
# Epoch 7/20
# 108/108 [==============================] - 0s 3ms/step - loss: 0.7260 - accuracy: 0.8704 - val_loss: 0.6800 - val_accuracy: 0.8704
# Epoch 8/20
# 108/108 [==============================] - 0s 3ms/step - loss: 0.8836 - accuracy: 0.8565 - val_loss: 0.5862 - val_accuracy: 0.8519
# Epoch 9/20
# 108/108 [==============================] - 0s 3ms/step - loss: 0.6045 - accuracy: 0.8565 - val_loss: 0.7498 - val_accuracy: 0.8333
# Epoch 10/20
# 108/108 [==============================] - 0s 3ms/step - loss: 0.4997 - accuracy: 0.8843 - val_loss: 0.5643 - val_accuracy: 0.8519
# Epoch 11/20
# 108/108 [==============================] - 0s 3ms/step - loss: 0.6363 - accuracy: 0.8611 - val_loss: 0.4588 - val_accuracy: 0.8704
# Epoch 12/20
# 108/108 [==============================] - 0s 3ms/step - loss: 0.4703 - accuracy: 0.8704 - val_loss: 0.9704 - val_accuracy: 0.7963
# Epoch 13/20
# 108/108 [==============================] - 0s 3ms/step - loss: 0.3790 - accuracy: 0.8750 - val_loss: 0.4625 - val_accuracy: 0.8704
# Epoch 14/20
# 108/108 [==============================] - 0s 3ms/step - loss: 0.3718 - accuracy: 0.8843 - val_loss: 0.3873 - val_accuracy: 0.8148
# Epoch 15/20
# 108/108 [==============================] - 0s 3ms/step - loss: 0.4390 - accuracy: 0.8796 - val_loss: 0.4630 - val_accuracy: 0.8519
# Epoch 16/20
# 108/108 [==============================] - 0s 3ms/step - loss: 0.2997 - accuracy: 0.9213 - val_loss: 0.6772 - val_accuracy: 0.8519
# Epoch 17/20
# 108/108 [==============================] - 0s 3ms/step - loss: 0.3844 - accuracy: 0.8704 - val_loss: 0.4323 - val_accuracy: 0.8148
# Epoch 18/20
# 108/108 [==============================] - 0s 3ms/step - loss: 0.3904 - accuracy: 0.8657 - val_loss: 0.4951 - val_accuracy: 0.8333
# Epoch 19/20
# 108/108 [==============================] - 0s 3ms/step - loss: 0.4590 - accuracy: 0.8519 - val_loss: 0.4427 - val_accuracy: 0.8519
# Epoch 20/20
# 108/108 [==============================] - 0s 3ms/step - loss: 0.3137 - accuracy: 0.9028 - val_loss: 0.3683 - val_accuracy: 0.8519

# %%
# Plot of accuracy vs epoch for train and test dataset
plt.plot(modelhistory.history['accuracy'])
plt.plot(modelhistory.history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# Plot of loss vs epoch for train and test dataset
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
y_pred = cnnmodel.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dl_acc = accuracy_score(y_pred, y_test)
dl_prec = precision_score(y_pred, y_test,average='weighted')
dl_rec = recall_score(y_pred, y_test,average='weighted')
dl_f1 = f1_score(y_pred, y_test,average='weighted')
dl_auroc = roc_auc_score(y_valid, clf.predict_proba(X_valid)[:, 1])
# Out:
# 3/3 [==============================] - 0s 2ms/step

# %%
storeResults('CNN',dl_acc,dl_prec,dl_rec,dl_f1,dl_auroc)

# %% [markdown]
# # GRU

# %%
from tensorflow.keras.layers import Dense, Dropout, Conv1D, MaxPooling1D, Flatten, LSTM, GRU, Bidirectional

# %%
def create_model(input_shape):
    # create model
    d = 0.25
    model = Sequential()
    
    model.add(GRU(32, input_shape=input_shape, activation='relu', return_sequences=True))
    model.add(Dropout(d))

    model.add(GRU(64, input_shape=input_shape, activation='relu', return_sequences=True))
    model.add(Dropout(d))
        
    model.add(GRU(128, input_shape=input_shape, activation='relu', return_sequences=True))
    model.add(Dropout(d))

    model.add(GRU(256, input_shape=input_shape, activation='relu', return_sequences=False))
    model.add(Dropout(d))
   
    model.add(Dense(32,kernel_initializer="uniform",activation='relu'))        
    model.add(Dense(2,kernel_initializer="uniform",activation='linear'))
    
    # compile model
    adam = tf.keras.optimizers.Adam(learning_rate=0.001, decay=0.00001)
    #model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    #model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
model = create_model(input_shape=(9,1))
model.summary()
# Out:
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_8 (GRU)                 (None, 9, 32)             3360
#
#  dropout_10 (Dropout)        (None, 9, 32)             0
#
#  gru_9 (GRU)                 (None, 9, 64)             18816
#
#  dropout_11 (Dropout)        (None, 9, 64)             0
#
#  gru_10 (GRU)                (None, 9, 128)            74496
#
#  dropout_12 (Dropout)        (None, 9, 128)            0
#
#  gru_11 (GRU)                (None, 256)               296448
#
#  dropout_13 (Dropout)        (None, 256)               0
#
#  dense_13 (Dense)            (None, 32)                8224
#
#  dense_14 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 401,410
# Trainable params: 401,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(X_train, Y_train, validation_data=(X_test, Y_test),epochs=20, batch_size=2, verbose=1)
# Out:
# Epoch 1/20
# 135/135 [==============================] - 10s 72ms/step - loss: 8.5366 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 2/20
# 135/135 [==============================] - 10s 72ms/step - loss: 8.3575 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 3/20
# 135/135 [==============================] - 10s 71ms/step - loss: 8.4769 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 4/20
# 135/135 [==============================] - 9s 69ms/step - loss: 8.6560 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 5/20
# 135/135 [==============================] - 10s 73ms/step - loss: 8.5963 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 6/20
# 135/135 [==============================] - 9s 69ms/step - loss: 8.4769 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 7/20
# 135/135 [==============================] - 9s 70ms/step - loss: 8.4172 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 8/20
# 135/135 [==============================] - 9s 69ms/step - loss: 8.4769 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 9/20
# 135/135 [==============================] - 10s 72ms/step - loss: 8.4769 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 10/20
# 135/135 [==============================] - 9s 70ms/step - loss: 8.5366 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 11/20
# 135/135 [==============================] - 10s 73ms/step - loss: 8.4769 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 12/20
# 135/135 [==============================] - 9s 70ms/step - loss: 8.5366 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 13/20
# 135/135 [==============================] - 10s 73ms/step - loss: 8.5366 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 14/20
# 135/135 [==============================] - 10s 72ms/step - loss: 8.5366 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 15/20
# 135/135 [==============================] - 10s 72ms/step - loss: 8.2978 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 16/20
# 135/135 [==============================] - 10s 73ms/step - loss: 8.2978 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 17/20
# 135/135 [==============================] - 10s 71ms/step - loss: 8.4172 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 18/20
# 135/135 [==============================] - 10s 71ms/step - loss: 8.4769 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 19/20
# 135/135 [==============================] - 10s 72ms/step - loss: 8.5366 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 20/20
# 135/135 [==============================] - 10s 73ms/step - loss: 8.5963 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

y_pred = model.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)


#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dl_acc = accuracy_score(y_pred, y_test)
dl_prec = precision_score(y_pred, y_test,average='weighted')
dl_rec = recall_score(y_pred, y_test,average='weighted')
dl_f1 = f1_score(y_pred, y_test,average='weighted')
dl_auroc = roc_auc_score(y_valid, clf.predict_proba(X_valid)[:, 1])
# Out:
# 3/3 [==============================] - 0s 19ms/step

# %%
storeResults('GRU',dl_acc,dl_prec,dl_rec,dl_f1,dl_auroc)

# %% [markdown]
# # Bi-LSTM

# %%
def create_model(input_shape):
    # create model
    d = 0.25
    model = Sequential()
    
    model.add(Bidirectional(LSTM(32, input_shape=input_shape, activation='relu', return_sequences=True)))
    model.add(Dropout(d))

    model.add(Bidirectional(LSTM(64, input_shape=input_shape, activation='relu', return_sequences=True)))
    model.add(Dropout(d))
        
    model.add(Bidirectional(LSTM(128, input_shape=input_shape, activation='relu', return_sequences=True)))
    model.add(Dropout(d))

    model.add(Bidirectional(LSTM(256, input_shape=input_shape, activation='relu', return_sequences=False)))
    model.add(Dropout(d))
   
    model.add(Dense(32,kernel_initializer="uniform",activation='relu'))        
    model.add(Dense(2,kernel_initializer="uniform",activation='linear'))
    
    # compile model
    adam = tf.keras.optimizers.Adam(learning_rate=0.001, decay=0.00001)
    #model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    #model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
model = create_model(input_shape=(9,1))
#model.summary()
# Out:
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
history=model.fit(X_train, Y_train, validation_data=(X_test, Y_test),epochs=20, batch_size=2, verbose=1)
# Out:
# Epoch 1/20
# 135/135 [==============================] - 19s 119ms/step - loss: 8.4770 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 2/20
# 135/135 [==============================] - 16s 117ms/step - loss: 8.5963 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 3/20
# 135/135 [==============================] - 15s 114ms/step - loss: 8.5963 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 4/20
# 135/135 [==============================] - 16s 117ms/step - loss: 8.5963 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 5/20
# 135/135 [==============================] - 16s 117ms/step - loss: 8.5963 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 6/20
# 135/135 [==============================] - 16s 116ms/step - loss: 8.5963 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 7/20
# 135/135 [==============================] - 15s 114ms/step - loss: 8.5963 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 8/20
# 135/135 [==============================] - 15s 114ms/step - loss: 8.5963 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 9/20
# 135/135 [==============================] - 16s 116ms/step - loss: 8.5963 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 10/20
# 135/135 [==============================] - 16s 115ms/step - loss: 8.5963 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 11/20
# 135/135 [==============================] - 15s 113ms/step - loss: 8.5963 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 12/20
# 135/135 [==============================] - 15s 113ms/step - loss: 8.5963 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 13/20
# 135/135 [==============================] - 16s 118ms/step - loss: 8.5963 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 14/20
# 135/135 [==============================] - 16s 119ms/step - loss: 8.5963 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 15/20
# 135/135 [==============================] - 16s 119ms/step - loss: 8.5963 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 16/20
# 135/135 [==============================] - 16s 119ms/step - loss: 8.5963 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 17/20
# 135/135 [==============================] - 16s 119ms/step - loss: 8.5963 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 18/20
# 135/135 [==============================] - 16s 119ms/step - loss: 8.5963 - accuracy: 0.5333 - val_loss: 5.9258 - val_accuracy: 0.3676
# Epoch 19/20
# 135/135 [==============================] - 16s 118ms/step - loss: 7.8203 - accuracy: 0.5333 - val_loss: 10.1923 - val_accuracy: 0.3676
# Epoch 20/20
# 135/135 [==============================] - 16s 119ms/step - loss: 7.5218 - accuracy: 0.5333 - val_loss: 10.1923 - val_accuracy: 0.3676

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('loss.png', format='png', dpi=1200)
plt.show()


# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig('accuracy.png', format='png', dpi=1200)
plt.show()

y_pred = model.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)


#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dl_acc = accuracy_score(y_pred, y_test)
dl_prec = precision_score(y_pred, y_test,average='weighted')
dl_rec = recall_score(y_pred, y_test,average='weighted')
dl_f1 = f1_score(y_pred, y_test,average='weighted')
dl_auroc = roc_auc_score(y_valid, clf.predict_proba(X_valid)[:, 1])
# Out:
# 3/3 [==============================] - 1s 41ms/step

# %%
storeResults('Bi-LSTM',dl_acc,dl_prec,dl_rec,dl_f1,dl_auroc)

# %% [markdown]
# # CNN + LSTM

# %%
import tensorflow as tf
tf.keras.backend.clear_session()

model_en = tf.keras.models.Sequential([tf.keras.layers.Conv1D(filters=64,kernel_size=5,strides=1,padding="causal",activation="relu",input_shape=(X_train.shape[1],X_train.shape[2])),
    tf.keras.layers.MaxPooling1D(pool_size=2, strides=1, padding="valid"),
    tf.keras.layers.Conv1D(filters=32, kernel_size=3, strides=1, padding="causal", activation="relu"),
    tf.keras.layers.MaxPooling1D(pool_size=2, strides=1, padding="valid"),
    tf.keras.layers.LSTM(128, return_sequences=True),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(32, activation="relu"),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(2)
])

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(5e-4,
                                                             decay_steps=1000000,
                                                             decay_rate=0.98,
                                                             staircase=False)

model_en.compile(loss=tf.keras.losses.MeanSquaredError(),
              optimizer=tf.keras.optimizers.SGD(learning_rate=lr_schedule, momentum=0.8),
              metrics=['acc'])
model_en.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 9, 64)             384
#
#  max_pooling1d (MaxPooling1D  (None, 8, 64)            0
#  )
#
#  conv1d_1 (Conv1D)           (None, 8, 32)             6176
#
#  max_pooling1d_1 (MaxPooling  (None, 7, 32)            0
#  1D)
#
#  lstm (LSTM)                 (None, 7, 128)            82432
#
#  flatten (Flatten)           (None, 896)               0
#
#  dense (Dense)               (None, 128)               114816
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 32)                4128
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 208,002
# Trainable params: 208,002
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelhistory = model_en.fit(X_train, Y_train, epochs=20, verbose=verbose, validation_split=0.2, batch_size = 2)
# Out:
# Epoch 1/20
# 108/108 [==============================] - 2s 10ms/step - loss: 0.2698 - acc: 0.6574 - val_loss: 0.2055 - val_acc: 0.6296
# Epoch 2/20
# 108/108 [==============================] - 1s 7ms/step - loss: 0.1834 - acc: 0.7685 - val_loss: 0.1351 - val_acc: 0.8333
# Epoch 3/20
# 108/108 [==============================] - 1s 7ms/step - loss: 0.1305 - acc: 0.8750 - val_loss: 0.1169 - val_acc: 0.8519
# Epoch 4/20
# 108/108 [==============================] - 1s 7ms/step - loss: 0.1205 - acc: 0.8796 - val_loss: 0.1265 - val_acc: 0.8333
# Epoch 5/20
# 108/108 [==============================] - 1s 7ms/step - loss: 0.1023 - acc: 0.9120 - val_loss: 0.1054 - val_acc: 0.8519
# Epoch 6/20
# 108/108 [==============================] - 1s 7ms/step - loss: 0.0997 - acc: 0.9074 - val_loss: 0.1143 - val_acc: 0.8333
# Epoch 7/20
# 108/108 [==============================] - 1s 7ms/step - loss: 0.1018 - acc: 0.8843 - val_loss: 0.1141 - val_acc: 0.8333
# Epoch 8/20
# 108/108 [==============================] - 1s 7ms/step - loss: 0.1027 - acc: 0.9028 - val_loss: 0.1227 - val_acc: 0.8333
# Epoch 9/20
# 108/108 [==============================] - 1s 7ms/step - loss: 0.1009 - acc: 0.8935 - val_loss: 0.1020 - val_acc: 0.8704
# Epoch 10/20
# 108/108 [==============================] - 1s 7ms/step - loss: 0.0956 - acc: 0.8889 - val_loss: 0.1012 - val_acc: 0.8704
# Epoch 11/20
# 108/108 [==============================] - 1s 7ms/step - loss: 0.0884 - acc: 0.9120 - val_loss: 0.1033 - val_acc: 0.8704
# Epoch 12/20
# 108/108 [==============================] - 1s 7ms/step - loss: 0.0982 - acc: 0.8889 - val_loss: 0.1088 - val_acc: 0.8333
# Epoch 13/20
# 108/108 [==============================] - 1s 7ms/step - loss: 0.0956 - acc: 0.9028 - val_loss: 0.1177 - val_acc: 0.8333
# Epoch 14/20
# 108/108 [==============================] - 1s 7ms/step - loss: 0.0895 - acc: 0.9213 - val_loss: 0.1037 - val_acc: 0.8704
# Epoch 15/20
# 108/108 [==============================] - 1s 7ms/step - loss: 0.0813 - acc: 0.9120 - val_loss: 0.1133 - val_acc: 0.8333
# Epoch 16/20
# 108/108 [==============================] - 1s 7ms/step - loss: 0.0890 - acc: 0.9120 - val_loss: 0.1050 - val_acc: 0.8519
# Epoch 17/20
# 108/108 [==============================] - 1s 7ms/step - loss: 0.0804 - acc: 0.9306 - val_loss: 0.1244 - val_acc: 0.8333
# Epoch 18/20
# 108/108 [==============================] - 1s 7ms/step - loss: 0.0850 - acc: 0.9259 - val_loss: 0.1373 - val_acc: 0.8333
# Epoch 19/20
# 108/108 [==============================] - 1s 7ms/step - loss: 0.0799 - acc: 0.9306 - val_loss: 0.1000 - val_acc: 0.8519
# Epoch 20/20
# 108/108 [==============================] - 1s 7ms/step - loss: 0.0866 - acc: 0.9259 - val_loss: 0.0952 - val_acc: 0.9074

# %%
# Plot of accuracy vs epoch for train and test dataset
plt.plot(modelhistory.history['acc'])
plt.plot(modelhistory.history['val_acc'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# Plot of loss vs epoch for train and test dataset
plt.plot(modelhistory.history['loss'])
plt.plot(modelhistory.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
y_pred = model_en.predict(X_test, verbose=1)
y_pred = np.argmax(y_pred,axis=1)

#y_prob = cnnmodel.predict_proba(X_test)[:, 1]

dl_acc = accuracy_score(y_pred, y_test)
dl_prec = precision_score(y_pred, y_test,average='weighted')
dl_rec = recall_score(y_pred, y_test,average='weighted')
dl_f1 = f1_score(y_pred, y_test,average='weighted')
dl_auroc = roc_auc_score(y_valid, clf.predict_proba(X_valid)[:, 1])
# Out:
# 3/3 [==============================] - 0s 5ms/step

# %%
storeResults('CNN + LSTM',dl_acc,dl_prec,dl_rec,dl_f1,dl_auroc)

# %% [markdown]
# # Transformer

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, BatchNormalization, Input
from keras import regularizers

# %%
# splitting the dataset 80% for training and 20% testing
X_train, X_test, y_train, y_test = train_test_split(X_res,y_res, test_size=0.20, random_state=42)

# %%
train_min = X_train.min()
train_max = X_train.max()
#x_train = (x_train - train_min) / (train_max - train_min)
#x_test = (x_test - train_min) / (train_max - train_min)

# %%
positives = x_train[y_train == 1]
negatives = x_train[y_train == 0]

# %%
## input layer 
input_layer = Input(shape=negatives.shape[1:])

## encoding part
encoded = Dense(100, activation='tanh', activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoded = BatchNormalization()(encoded)
encoded = Dense(75, activation='tanh')(encoded)
encoded = BatchNormalization()(encoded)
encoded = Dense(50, activation='relu')(encoded)
encoded = BatchNormalization()(encoded)
encoded = Dense(25, activation='relu')(encoded)
encoded = BatchNormalization()(encoded)
encoded = Dense(7, activation='relu')(encoded)

## decoding part
decoded = Dense(7, activation='relu')(encoded)
decoded = BatchNormalization()(decoded)
decoded = Dense(25, activation='relu')(decoded)
decoded = BatchNormalization()(decoded)
decoded = Dense(50, activation='relu')(decoded)
decoded = BatchNormalization()(decoded)
decoded = Dense(75, activation='tanh')(decoded)
decoded = BatchNormalization()(decoded)
decoded = Dense(100, activation='tanh')(decoded)

## output layer
output_layer = Dense(negatives.shape[1], activation='relu')(decoded)

# %%
autoencoder = Model(input_layer, output_layer)
autoencoder.compile(optimizer="adadelta", loss="mse", metrics=['accuracy'])

# %%
autoencoder.fit(negatives, negatives, batch_size = 2, epochs = 10, shuffle = True)
# Out:
# Epoch 1/10
# 72/72 [==============================] - 2s 17ms/step - loss: 0.3168 - accuracy: 0.0972
# Epoch 2/10
# 72/72 [==============================] - 1s 16ms/step - loss: 0.3019 - accuracy: 0.1111
# Epoch 3/10
# 72/72 [==============================] - 1s 15ms/step - loss: 0.3070 - accuracy: 0.1389
# Epoch 4/10
# 72/72 [==============================] - 1s 13ms/step - loss: 0.2989 - accuracy: 0.2014
# Epoch 5/10
# 72/72 [==============================] - 1s 13ms/step - loss: 0.3096 - accuracy: 0.1181
# Epoch 6/10
# 72/72 [==============================] - 1s 13ms/step - loss: 0.3206 - accuracy: 0.1458
# Epoch 7/10
# 72/72 [==============================] - 1s 14ms/step - loss: 0.3498 - accuracy: 0.1319
# Epoch 8/10
# 72/72 [==============================] - 1s 16ms/step - loss: 0.3088 - accuracy: 0.0972
# Epoch 9/10
# 72/72 [==============================] - 1s 15ms/step - loss: 0.3161 - accuracy: 0.0764
# Epoch 10/10
# 72/72 [==============================] - 1s 15ms/step - loss: 0.3233 - accuracy: 0.1458

# %%
hidden_representation = Sequential()
hidden_representation.add(autoencoder.layers[0])
hidden_representation.add(autoencoder.layers[1])
hidden_representation.add(autoencoder.layers[2])
hidden_representation.add(autoencoder.layers[3])
hidden_representation.add(autoencoder.layers[4])
hidden_representation.add(autoencoder.layers[5])
hidden_representation.add(autoencoder.layers[6])
hidden_representation.add(autoencoder.layers[7])
hidden_representation.add(autoencoder.layers[8])
hidden_representation.add(autoencoder.layers[9])

# %%
x_train_transformed = hidden_representation.predict(X_train)
x_test_transformed = hidden_representation.predict(X_test)
# Out:
# WARNING:tensorflow:5 out of the last 16 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001D05200E290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 9/9 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 1ms/step

# %%
predictor = Sequential()
predictor.add(Dense(64, activation='relu', input_shape=x_train_transformed.shape[1:]))
predictor.add(BatchNormalization())
predictor.add(Dropout(0.25))
predictor.add(Dense(64, activation='relu'))
predictor.add(BatchNormalization())
predictor.add(Dense(64, activation='relu'))
predictor.add(BatchNormalization())
predictor.add(Dense(64, activation='tanh'))
predictor.add(BatchNormalization())
predictor.add(Dense(1, activation='sigmoid'))

# %%
predictor.compile(optimizer='adam', loss = 'binary_crossentropy', metrics=['accuracy'])
history = predictor.fit(x_train_transformed, y_train, batch_size=2, epochs=20, shuffle=True)
# Out:
# Epoch 1/20
# 135/135 [==============================] - 2s 10ms/step - loss: 0.8376 - accuracy: 0.5111
# Epoch 2/20
# 135/135 [==============================] - 1s 10ms/step - loss: 0.8203 - accuracy: 0.5111
# Epoch 3/20
# 135/135 [==============================] - 1s 10ms/step - loss: 0.7873 - accuracy: 0.5037
# Epoch 4/20
# 135/135 [==============================] - 1s 9ms/step - loss: 0.7691 - accuracy: 0.5407
# Epoch 5/20
# 135/135 [==============================] - 1s 10ms/step - loss: 0.7892 - accuracy: 0.5037
# Epoch 6/20
# 135/135 [==============================] - 1s 10ms/step - loss: 0.7353 - accuracy: 0.5741
# Epoch 7/20
# 135/135 [==============================] - 1s 10ms/step - loss: 0.7222 - accuracy: 0.5481
# Epoch 8/20
# 135/135 [==============================] - 1s 10ms/step - loss: 0.7212 - accuracy: 0.5370
# Epoch 9/20
# 135/135 [==============================] - 1s 9ms/step - loss: 0.7492 - accuracy: 0.5741
# Epoch 10/20
# 135/135 [==============================] - 1s 10ms/step - loss: 0.7288 - accuracy: 0.5963
# Epoch 11/20
# 135/135 [==============================] - 1s 10ms/step - loss: 0.7257 - accuracy: 0.5185
# Epoch 12/20
# 135/135 [==============================] - 1s 9ms/step - loss: 0.7258 - accuracy: 0.5074
# Epoch 13/20
# 135/135 [==============================] - 1s 10ms/step - loss: 0.7554 - accuracy: 0.5000
# Epoch 14/20
# 135/135 [==============================] - 1s 10ms/step - loss: 0.6925 - accuracy: 0.5741
# Epoch 15/20
# 135/135 [==============================] - 1s 10ms/step - loss: 0.7097 - accuracy: 0.5407
# Epoch 16/20
# 135/135 [==============================] - 1s 10ms/step - loss: 0.7040 - accuracy: 0.5407
# Epoch 17/20
# 135/135 [==============================] - 1s 9ms/step - loss: 0.6937 - accuracy: 0.5704
# Epoch 18/20
# 135/135 [==============================] - 1s 10ms/step - loss: 0.7089 - accuracy: 0.5481
# Epoch 19/20
# 135/135 [==============================] - 1s 10ms/step - loss: 0.6692 - accuracy: 0.5852
# Epoch 20/20
# 135/135 [==============================] - 1s 10ms/step - loss: 0.7048 - accuracy: 0.5222

# %%
y_pred = predictor.predict(x_test_transformed)
y_pred = np.argmax(y_pred,axis=1)

dl_acc = accuracy_score(y_pred, y_test)
dl_prec = precision_score(y_pred, y_test,average='weighted')
dl_rec = recall_score(y_pred, y_test,average='weighted')
dl_f1 = f1_score(y_pred, y_test,average='weighted')
dl_auroc = roc_auc_score(y_valid, clf.predict_proba(X_valid)[:, 1])
# Out:
# 3/3 [==============================] - 0s 2ms/step

# %%
storeResults('Transformer',dl_acc,dl_prec,dl_rec,dl_f1,dl_auroc)

# %% [markdown]
# # Comparison

# %%
#creating dataframe
result = pd.DataFrame({ 'ML Model' : ML_Model,
                        'Accuracy' : accuracy,
                        'Precision': precision,
                        'Recall'   : recall,
                        'F1-Score': f1score,
                       'AUC ROC': auc
                      })

# %%
result
# Out:
#                ML Model  Accuracy  Precision  Recall  F1-Score  AUC ROC
# 0   Logistic Regression     0.853      0.873   0.853     0.850    0.969
# 1                   SVM     0.824      0.855   0.824     0.820    0.959
# 2            NaiveBayes     0.882      0.886   0.882     0.881    0.934
# 3          RandomForest     0.853      0.887   0.853     0.850    1.000
# 4              AdaBoost     0.838      0.852   0.838     0.835    0.997
# 5               XGBoost     0.882      0.904   0.882     0.880    1.000
# 6                   MLP     0.882      0.886   0.882     0.881    0.985
# 7              LightGBM     0.838      0.864   0.838     0.835    0.975
# 8              Proposed     0.853      0.873   0.853     0.850    0.997
# 9             Extension     1.000      1.000   1.000     1.000    0.948
# 10                  FNN     0.868      0.869   0.868     0.868    0.948
# 11                  ANN     0.368      1.000   0.368     0.538    0.948
# 12                  CNN     0.838      0.864   0.838     0.835    1.000
# 13                  GRU     0.368      1.000   0.368     0.538    1.000
# 14              Bi-LSTM     0.368      1.000   0.368     0.538    1.000
# 15           CNN + LSTM     0.853      0.855   0.853     0.851    1.000
# 16          Transformer     0.368      1.000   0.368     0.538    1.000

# %% [markdown]
# # Modelling

# %%
import joblib
filename = 'models/model_pc.sav'
joblib.dump(clf, filename)
# Out:
# ['models/model_pc.sav']

# %% [markdown]
# # Graph

# %%
classifier = ML_Model
y_pos = np.arange(len(classifier))

# %% [markdown]
# # Accuracy

# %%
import matplotlib.pyplot as plt2
plt2.barh(y_pos, accuracy, align='center', alpha=0.5,color='blue')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Accuracy Score')
plt2.title('Classification Performance')
plt2.show()

# %% [markdown]
# # Precision

# %%
plt2.barh(y_pos, precision, align='center', alpha=0.5,color='red')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Precision Score')
plt2.title('Classification Performance')
plt2.show()

# %% [markdown]
# # Recall

# %%
plt2.barh(y_pos, recall, align='center', alpha=0.5,color='yellow')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Recall Score')
plt2.title('Classification Performance')
plt2.show()

# %% [markdown]
# # F1 Score

# %%
plt2.barh(y_pos, f1score, align='center', alpha=0.5,color='purple')
plt2.yticks(y_pos, classifier)
plt2.xlabel('F1 Score')
plt2.title('Classification Performance')
plt2.show()

# %% [markdown]
# # AUC ROC

# %%
plt2.barh(y_pos, auc, align='center', alpha=0.5,color='brown')
plt2.yticks(y_pos, classifier)
plt2.xlabel('AUC ROC')
plt2.title('Classification Performance')
plt2.show()
